# %%
import pandas as pd

# %%
final_dataset = pd.read_csv('final_dataset.csv')
final_dataset['profile'].unique()
# Out:
# array(['media_library_platform', 'commerce_platform',
#        'information_reference_platform', 'reservation_service_platform',
#        'developer_collaboration_platform', 'content_sharing_platform',
#        'professional_network_platform', 'knowledge_community_platform'],
#       dtype=object)

# %%
final_dataset.groupby('profile').size()
# Out:
# profile
# commerce_platform                   256
# content_sharing_platform            270
# developer_collaboration_platform     26
# information_reference_platform      181
# knowledge_community_platform        109
# media_library_platform               88
# professional_network_platform        64
# reservation_service_platform         64
# dtype: int64
